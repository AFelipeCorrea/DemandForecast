# %% [markdown]
# # Carga de Paquetes y Librerias

# %%
# Basic packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import seaborn as sns
from pandas.plotting import scatter_matrix
from tabulate import tabulate
from numpy import array
import datetime as dt           # Permite trabajar con fechas

# Machine learning packages
from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline


# Reducción de dimensiones
from sklearn.decomposition import PCA

# Regresión lineal
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# Métricas de rendimiento
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error, r2_score, mean_absolute_percentage_error
import scipy.stats as stats
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
from scipy.stats import bartlett

# TensorFlow ≥2.0-preview is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

# Pretty print
from pprint import pprint

#SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', '.*do not.*', )
warnings.warn('DelftStack')
warnings.warn('Do not show this message')

# %%
def TrainingSets(data, dataξ,step_back):
    train_data  = data.copy()
    train_dataξ = dataξ.copy()
    # training set
    X_train, ξ_train = [], []
    for i in range(len(train_data)-step_back - 1):
        a = train_data[i:(i+step_back)]
        X_train.append(a)
        ξ_train.append(train_dataξ[i + step_back])
    X_train = np.array(X_train); ξ_train = np.array(ξ_train);
    return  X_train, ξ_train

# %% [markdown]
# # Carga de Base de Datos

# %%
#cargar datos desde drive acceso libre
FILEID = "1feevcPPLWwZS2_ixxgKUoVi25NJQ0uJ_"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O Departamentos.zip && rm -rf /tmp/cookies.txt
# !unzip Departamentos.zip
# !dir
# Out:
# --2023-06-19 22:23:08--  https://docs.google.com/uc?export=download&confirm=&id=1feevcPPLWwZS2_ixxgKUoVi25NJQ0uJ_
# Resolving docs.google.com (docs.google.com)... 64.233.170.101, 64.233.170.113, 64.233.170.100, ...
# Connecting to docs.google.com (docs.google.com)|64.233.170.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-6k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8aklgf96i3adqj1akue6pg65f8eugb6i/1687213350000/15940467605774616319/*/1feevcPPLWwZS2_ixxgKUoVi25NJQ0uJ_?e=download&uuid=ea13f72f-0dd2-45e3-b884-a7c3e57ff331 [following]
# Warning: wildcards not supported in HTTP.
# --2023-06-19 22:23:10--  https://doc-0c-6k-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/8aklgf96i3adqj1akue6pg65f8eugb6i/1687213350000/15940467605774616319/*/1feevcPPLWwZS2_ixxgKUoVi25NJQ0uJ_?e=download&uuid=ea13f72f-0dd2-45e3-b884-a7c3e57ff331
# Resolving doc-0c-6k-docs.googleusercontent.com (doc-0c-6k-docs.googleusercontent.com)... 142.251.12.132, 2404:6800:4003:c11::84
# Connecting to doc-0c-6k-docs.googleusercontent.com (doc-0c-6k-docs.googleusercontent.com)|142.251.12.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15699299 (15M) [application/x-zip-compressed]
# Saving to: ‘Departamentos.zip’
#
# Departamentos.zip   100%[===================>]  14.97M  --.-KB/s    in 0.09s
#
# 2023-06-19 22:23:11 (170 MB/s) - ‘Departamentos.zip’ saved [15699299/15699299]
#
# Archive:  Departamentos.zip
#   inflating: Demanda_Arreglo_LSTM_Rd_CL.xlsx
#   inflating: Demanda_Arreglo_LSTM_Rd_Sin.xlsx
#   inflating: Demanda_Arreglo_LSTM_Rd.xlsx
#   inflating: Demanda_Arreglo_Mean.xlsx
# Demanda_Arreglo_LSTM_Rd_CL.xlsx   Demanda_Arreglo_Mean.xlsx
# Demanda_Arreglo_LSTM_Rd_Sin.xlsx  Departamentos.zip
# Demanda_Arreglo_LSTM_Rd.xlsx	  sample_data

# %%
ls
# Out:
# Demanda_Arreglo_LSTM_Rd_CL.xlsx   Demanda_Arreglo_Mean.xlsx
# Demanda_Arreglo_LSTM_Rd_Sin.xlsx  Departamentos.zip
# Demanda_Arreglo_LSTM_Rd.xlsx      sample_data/

# %%
df=pd.read_excel('/content/Demanda_Arreglo_Mean.xlsx')
df.fillna(df.mean(), inplace=True)

# %%
df = df.drop('Date', axis=1)
# Se establese nuevamente en el indice temporal en la nueva variable 'a', y al DataFrame se incliye la informacion de frecuencia horaria 'H' de la base de datos
date_rng = pd.date_range(start='2020-10-01', end='2023-01-01', freq='H')
# Establece el índice del DataFrame a las fechas generadas
df.set_index(date_rng[0:-1], inplace=True)

# %%
df.plot(kind='line',figsize=(10,7.5),title='Demanda Energia Horaria en Colombia kWh', grid=True, ylabel='kWh', xlabel='Fecha',xlim=('2022-12-01','2022-12-31'))
# Out:
# <Axes: title={'center': 'Demanda Energia Horaria en Colombia kWh'}, xlabel='Fecha', ylabel='kWh'>

# %% [markdown]
# # Normalizacion

# %%
df1=df.copy()

# %%
#scaler = StandardScaler()
scaler = MinMaxScaler()
scaler.fit(df1)
df1=scaler.transform(df1)
#plt.plot(df1)

# %%
plt.plot(df1[0:24,:])
plt.show()

# %%
Ts1=df1.copy()
out=Ts1[:,0]
print('Tamaño Serie Horaria: ', Ts1.shape)
print('Tamaño Serie Salida: ', out.shape)
# Out:
# Tamaño Serie Horaria:  (19728, 24)
# Tamaño Serie Salida:  (19728,)

# %% [markdown]
# # Modelos DL

# %% [markdown]
# ## Time Step=1

# %% [markdown]
# ### Conjunto de Entrenamiento

# %%
#  Particion X,Y y Time_step/step_back/window
step_back = 1

X1, Y1 = TrainingSets(data = Ts1, dataξ = out,step_back=step_back)


#  Particion Train_Test

Part = 0.8

# Serie 1
X_test1 = X1[int(len(X1)*0.8):]
X_train1 = X1[:int(len(X1)*0.8)]
# X_test1=X_test1[:,0,:]
# X_train1=X_train1[:,0,:]

Y_test1 = Y1[int(len(Y1)*0.8):]
Y_train1 = Y1[:int(len(Y1)*0.8)]
# Y_test1=Y_test1[:,0]
# Y_train1=Y_train1[:,0]

# %%
print('Tamaño X_train1: ', X_train1.shape, 'Tamaño Y_train1: ', Y_train1.shape, )
print('Tamaño X_test1: ', X_test1.shape, 'Tamaño Y_test1: ', Y_test1.shape, )
print('-----------------------------------------------------------------------')
# Out:
# Tamaño X_train1:  (15780, 1, 24) Tamaño Y_train1:  (15780,)
# Tamaño X_test1:  (3946, 1, 24) Tamaño Y_test1:  (3946,)
# -----------------------------------------------------------------------

# %%
# Nuemero de Epocas
N=100
bsz=512

# %%
callbacks = [keras.callbacks.ModelCheckpoint("best_model.h5", save_best_only=True, monitor="val_loss"),
             keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=0.0001),
             keras.callbacks.EarlyStopping(monitor="val_loss", patience=7, verbose=1),]

# %%
X_train1.shape[1]
# Out:
# 1

# %% [markdown]
# ### LSTM

# %%
model_LSTM = keras.models.Sequential([
                                     keras.layers.LSTM(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.LSTM(100, return_sequences=True),
                                     keras.layers.LSTM(100, return_sequences=True),
                                     keras.layers.LSTM(1)
])
model_LSTM.summary()

# Training

model_LSTM.compile(loss="mse", optimizer="adam", metrics=['mae', 'mse'])
history = model_LSTM.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1,
-04
# Epoch 50/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023 - val_loss: 0.0038 - val_mae: 0.0461 - val_mse: 0.0038 - lr: 1.2500e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023 - val_loss: 0.0038 - val_mae: 0.0464 - val_mse: 0.0038 - lr: 1.2500e-04
# Epoch 51: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ANN

# %%
model_ANN = keras.models.Sequential([
                                     keras.layers.Dense(100,input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.Dense(100),
                                     keras.layers.Dense(100),
                                     keras.layers.Dense(1)
])
model_ANN.summary()
# [step_back,Ts1.shape[1]] [Ts1.shape[1],step_back]

# Training

model_ANN.compile(loss="mse", optimizer="adam", metrics=['mae', 'mse'])
history = model_ANN.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, validation_split=0.2) # callbacks=callbacks,
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 100)            2500
#
#  dense_1 (Dense)             (None, 1, 100)            10100
#
#  dense_2 (Dense)             (None, 1, 100)            10100
#
#  dense_3 (Dense)             (None, 1, 1)              101
#
# =================================================================
# Total params: 22,801
# Trainable params: 22,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 3s 22ms/step - loss: 0.1205 - mae: 0.2729 - mse: 0.1205 - val_loss: 0.0462 - val_mae: 0.1811 - val_mse: 0.0462
# Epoch 2/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0463 - mae: 0.1848 - mse: 0.0463 - val_loss: 0.0407 - val_mae: 0.1772 - val_mse: 0.0407
# Epoch 3/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0425 - mae: 0.1799 - mse: 0.0425 - val_loss: 0.0460 - val_mae: 0.1849 - val_mse: 0.0460
# Epoch 4/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0421 - mae: 0.1794 - mse: 0.0421 - val_loss: 0.0451 - val_mae: 0.1836 - val_mse: 0.0451
# Epoch 5/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0420 - mae: 0.1792 - mse: 0.0420 - val_loss: 0.0443 - val_mae: 0.1826 - val_mse: 0.0443
# Epoch 6/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0417 - mae: 0.1790 - mse: 0.0417 - val_loss: 0.0436 - val_mae: 0.1817 - val_mse: 0.0436
# Epoch 7/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0419 - mae: 0.1791 - mse: 0.0419 - val_loss: 0.0474 - val_mae: 0.1868 - val_mse: 0.0474
# Epoch 8/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0421 - mae: 0.1794 - mse: 0.0421 - val_loss: 0.0432 - val_mae: 0.1811 - val_mse: 0.0432
# Epoch 9/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0415 - mae: 0.1787 - mse: 0.0415 - val_loss: 0.0427 - val_mae: 0.1805 - val_mse: 0.0427
# Epoch 10/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0412 - mae: 0.1783 - mse: 0.0412 - val_loss: 0.0439 - val_mae: 0.1820 - val_mse: 0.0439
# Epoch 11/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0411 - mae: 0.1782 - mse: 0.0411 - val_loss: 0.0458 - val_mae: 0.1846 - val_mse: 0.0458
# Epoch 12/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0412 - mae: 0.1783 - mse: 0.0412 - val_loss: 0.0480 - val_mae: 0.1877 - val_mse: 0.0480
# Epoch 13/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0416 - mae: 0.1788 - mse: 0.0416 - val_loss: 0.0395 - val_mae: 0.1758 - val_mse: 0.0395
# Epoch 14/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0415 - mae: 0.1785 - mse: 0.0415 - val_loss: 0.0461 - val_mae: 0.1851 - val_mse: 0.0461
# Epoch 15/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0411 - mae: 0.1781 - mse: 0.0411 - val_loss: 0.0420 - val_mae: 0.1795 - val_mse: 0.0420
# Epoch 16/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0411 - mae: 0.1783 - mse: 0.0411 - val_loss: 0.0423 - val_mae: 0.1799 - val_mse: 0.0423
# Epoch 17/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0413 - mae: 0.1785 - mse: 0.0413 - val_loss: 0.0453 - val_mae: 0.1840 - val_mse: 0.0453
# Epoch 18/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.
# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### GRU

# %%
model_GRU = keras.models.Sequential([
                                     keras.layers.GRU(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.GRU(100, return_sequences=True),
                                     keras.layers.GRU(100, return_sequences=True),
                                     keras.layers.GRU(1)
])
model_GRU.summary()

# Training
metrics=['mae', 'mse']

model_GRU.compile(loss="mse", optimizer="adam", metrics=metrics)
history = model_GRU.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 100)            37800
#
#  gru_1 (GRU)                 (None, 1, 100)            60600
#
#  gru_2 (GRU)                 (None, 1, 100)            60600
#
#  gru_3 (GRU)                 (None, 1)                 309
#
# =================================================================
# Total params: 159,309
# Trainable params: 159,309
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 9s 57ms/step - loss: 0.0972 - mae: 0.2466 - mse: 0.0972 - val_loss: 0.0254 - val_mae: 0.1371 - val_mse: 0.0254 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0232 - mae: 0.1322 - mse: 0.0232 - val_loss: 0.0134 - val_mae: 0.1013 - val_mse: 0.0134 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0064 - mae: 0.0672 - mse: 0.0064 - val_loss: 0.0038 - val_mae: 0.0517 - val_mse: 0.0038 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0034 - mae: 0.0477 - mse: 0.0034 - val_loss: 0.0030 - val_mae: 0.0456 - val_mse: 0.0030 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0028 - mae: 0.0432 - mse: 0.0028 - val_loss: 0.0028 - val_mae: 0.0433 - val_mse: 0.0028 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0024 - mae: 0.0395 - mse: 0.0024 - val_loss: 0.0025 - val_mae: 0.0400 - val_mse: 0.0025 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0021 - mae: 0.0363 - mse: 0.0021 - val_loss: 0.0023 - val_mae: 0.0373 - val_mse: 0.0023 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0020 - mae: 0.0343 - mse: 0.0020 - val_loss: 0.0021 - val_mae: 0.0357 - val_mse: 0.0021 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0019 - mae: 0.0332 - mse: 0.0019 - val_loss: 0.0021 - val_mae: 0.0358 - val_mse: 0.0021 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0018 - mae: 0.0326 - mse: 0.0018 - val_loss: 0.0019 - val_mae: 0.0336 - val_mse: 0.0019 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018 - mae: 0.0322 - mse: 0.0018 - val_loss: 0.0020 - val_mae: 0.0347 - val_mse: 0.0020 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0315 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0340 - val_mse: 0.0020 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0017 - mae: 0.0310 - mse: 0.0017 - val_loss: 0.0019 - val_mae: 0.0335 - val_mse: 0.0019 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0307 - mse: 0.0017 - val_loss: 0.0018 - val_mae: 0.0330 - val_mse: 0.0018 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0306 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0333 - val_mse: 0.0019 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0302 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0328 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 17/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0302 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0329 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0300 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0330 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 19/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0300 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0331 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0016 - mae: 0.0300 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 21/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0301 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 22/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0298 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 23/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - mae: 0.0297 - mse: 0.0016 - val_loss: 0.0020 - val_mae: 0.0337 - val_mse: 0.0020 - lr: 5.0000e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - mae: 0.0297 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0320 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0300 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0332 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0327 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0333 - val_mse: 0.0019 - lr: 2.5000e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0295 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0326 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015 - mae: 0.0295 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0325 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015 - mae: 0.0294 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0325 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0294 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018 - lr: 1.2500e-04
# Epoch 31: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### RNN

# %%
model_RNN = keras.models.Sequential([
                                     keras.layers.SimpleRNN(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.SimpleRNN(100, return_sequences=True),
                                     keras.layers.SimpleRNN(100, return_sequences=True),
                                     keras.layers.SimpleRNN(1)
])
model_RNN.summary()

# Training

metrics=['mae', 'mse']
model_RNN.compile(loss="mse", optimizer="adam", metrics=metrics)
history = model_RNN.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 100)            12500
#
#  simple_rnn_1 (SimpleRNN)    (None, 1, 100)            20100
#
#  simple_rnn_2 (SimpleRNN)    (None, 1, 100)            20100
#
#  simple_rnn_3 (SimpleRNN)    (None, 1)                 102
#
# =================================================================
# Total params: 52,802
# Trainable params: 52,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 5s 31ms/step - loss: 0.0267 - mae: 0.1270 - mse: 0.0267 - val_loss: 0.0126 - val_mae: 0.1006 - val_mse: 0.0126 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0045 - mae: 0.0534 - mse: 0.0045 - val_loss: 0.0041 - val_mae: 0.0512 - val_mse: 0.0041 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0030 - mae: 0.0435 - mse: 0.0030 - val_loss: 0.0031 - val_mae: 0.0436 - val_mse: 0.0031 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0027 - mae: 0.0411 - mse: 0.0027 - val_loss: 0.0028 - val_mae: 0.0415 - val_mse: 0.0028 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0026 - mae: 0.0399 - mse: 0.0026 - val_loss: 0.0027 - val_mae: 0.0404 - val_mse: 0.0027 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0025 - mae: 0.0389 - mse: 0.0025 - val_loss: 0.0029 - val_mae: 0.0416 - val_mse: 0.0029 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0024 - mae: 0.0381 - mse: 0.0024 - val_loss: 0.0026 - val_mae: 0.0397 - val_mse: 0.0026 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0022 - mae: 0.0370 - mse: 0.0022 - val_loss: 0.0024 - val_mae: 0.0382 - val_mse: 0.0024 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0022 - mae: 0.0364 - mse: 0.0022 - val_loss: 0.0026 - val_mae: 0.0389 - val_mse: 0.0026 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0021 - mae: 0.0356 - mse: 0.0021 - val_loss: 0.0023 - val_mae: 0.0371 - val_mse: 0.0023 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0020 - mae: 0.0349 - mse: 0.0020 - val_loss: 0.0021 - val_mae: 0.0360 - val_mse: 0.0021 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0019 - mae: 0.0341 - mse: 0.0019 - val_loss: 0.0023 - val_mae: 0.0366 - val_mse: 0.0023 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0019 - mae: 0.0333 - mse: 0.0019 - val_loss: 0.0022 - val_mae: 0.0357 - val_mse: 0.0022 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0018 - mae: 0.0330 - mse: 0.0018 - val_loss: 0.0020 - val_mae: 0.0346 - val_mse: 0.0020 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0018 - mae: 0.0324 - mse: 0.0018 - val_loss: 0.0022 - val_mae: 0.0356 - val_mse: 0.0022 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0018 - mae: 0.0321 - mse: 0.0018 - val_loss: 0.0018 - val_mae: 0.0330 - val_mse: 0.0018 - lr: 0.0010
# Epoch 17/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0317 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0343 - val_mse: 0.0020 - lr: 0.0010
# Epoch 18/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017 - val_loss: 0.0018 - val_mae: 0.0322 - val_mse: 0.0018 - lr: 0.0010
# Epoch 19/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017 - val_loss: 0.0018 - val_mae: 0.0322 - val_mse: 0.0018 - lr: 0.0010
# Epoch 20/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - mae: 0.0308 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0324 - val_mse: 0.0017 - lr: 0.0010
# Epoch 21/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0016 - mae: 0.0304 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0318 - val_mse: 0.0017 - lr: 0.0010
# Epoch 22/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - mae: 0.0299 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0313 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0016 - mae: 0.0300 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0315 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 24/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0016 - mae: 0.0299 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0321 - val_mse: 0.0018 - lr: 5.0000e-04
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0318 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0015 - mae: 0.0294 - mse: 0.0015 - val_loss: 0.0019 - val_mae: 0.0328 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - mae: 0.0295 - mse: 0.0016 - val_loss: 0.0016 - val_mae: 0.0307 - val_mse: 0.0016 - lr: 5.0000e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0295 - mse: 0.0015 - val_loss: 0.0019 - val_mae: 0.0328 - val_mse: 0.0019 - lr: 2.5000e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - mae: 0.0292 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0319 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 30/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0292 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0322 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 31/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - mae: 0.0292 - mse: 0.0015 - val_loss: 0.0017 - val_mae: 0.0309 - val_mse: 0.0017 - lr: 2.5000e-04
# Epoch 32/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0015 - mae: 0.0291 - mse: 0.0015 - val_loss: 0.0017 - val_mae: 0.0312 - val_mse: 0.0017 - lr: 2.5000e-04
# Epoch 33/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - mae: 0.0289 - mse: 0.0015 - val_loss: 0.0017 - val_mae: 0.0315 - val_mse: 0.0017 - lr: 1.2500e-04
# Epoch 34/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - mae: 0.0290 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0320 - val_mse: 0.0018 - lr: 1.2500e-04
# Epoch 34: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Medidas de Rendimiento

# %%
forecasting_RNN  = model_RNN.predict(X_test1)
forecasting_GRU  = model_GRU.predict(X_test1)
forecasting_LSTM = model_LSTM.predict(X_test1)
forecasting_ANN = model_ANN.predict(X_test1)

forecasting_DL = [forecasting_RNN, forecasting_GRU, forecasting_LSTM,forecasting_ANN.reshape(forecasting_ANN.shape[0],1)]
model_names_DL = ['RNN', 'GRU', 'LSTM','ANN']

plt.figure(figsize=(7.5,5))
plt.plot(Y_test1, label='Target')
for i in range(len(forecasting_DL)):
  plt.plot(forecasting_DL[i], label=model_names_DL[i], linestyle='--')
plt.xlim(3850,len(forecasting_DL[i])) # 3850
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize='8')
plt.grid()
plt.show()


col_names, MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var = ['Metrics','RNN', 'GRU', 'LSTM','ANN'], ["MSE"], ["RMSE"], ["MAE"], ["R2"],['cnSMAPE'],['P_Value_PS'],['P_Value_TT'], ['P_Value_Var']
for k in range(4):
  MSE.append(round(mean_squared_error(Y_test1, forecasting_DL[k], squared=False),5))
  RMSE.append(mean_squared_error(Y_test1, forecasting_DL[k], squared=True))
  MAE.append(round(mean_absolute_error(Y_test1, forecasting_DL[k]),5))
  R2.append(round(r2_score(Y_test1, forecasting_DL[k]),5))
  mape=mean_absolute_percentage_error(Y_test1, forecasting_DL[k])
  smape = 2 * mape * 100 / (100 - mape)
  cnSMAPE.append(round(1-(smape/2),5))
  correlation, p_value = stats.pearsonr(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_PS.append(p_value)
  correlation, p_value = stats.ttest_ind(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_TT.append(p_value)
  statistic, p_value3 = bartlett(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_Var.append(p_value3)

tablas = [MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var]

print(tabulate(tablas, headers=col_names, tablefmt="fancy_grid"))
# Out:
# 124/124 [==============================] - 1s 3ms/step
# 124/124 [==============================] - 2s 3ms/step
# 124/124 [==============================] - 2s 3ms/step
# 124/124 [==============================] - 0s 2ms/step
# ╒═════════════╤════════════╤════════════╤═════════════╤═══════════════╕
# │ Metrics     │        RNN │        GRU │        LSTM │           ANN │
# ╞═════════════╪════════════╪════════════╪═════════════╪═══════════════╡
# │ MSE         │ 0.04395    │ 0.04482    │ 0.06878     │  0.21392      │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ RMSE        │ 0.00193122 │ 0.00200922 │ 0.00473068  │  0.0457618    │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ MAE         │ 0.0332     │ 0.03449    │ 0.05145     │  0.18696      │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ R2          │ 0.95208    │ 0.95015    │ 0.88262     │ -0.13549      │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ cnSMAPE     │ 0.943      │ 0.9394     │ 0.92217     │  0.67257      │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_PS  │ 0          │ 0          │ 0           │  1.94796e-52  │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_TT  │ 0.336745   │ 0.350221   │ 9.83274e-12 │  3.19568e-108 │
# ├─────────────┼────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_Var │ 0.00356682 │ 0.0022869  │ 1.62048e-38 │  0            │
# ╘═════════════╧════════════╧════════════╧═════════════╧═══════════════╛

# %%
forecasting_RNN  = model_RNN.predict(X_test1)
forecasting_GRU  = model_GRU.predict(X_test1)
forecasting_LSTM = model_LSTM.predict(X_test1)

forecasting_DL = [forecasting_RNN, forecasting_GRU, forecasting_LSTM]
model_names_DL = ['RNN', 'GRU', 'LSTM']

plt.figure(figsize=(7.5,5))
plt.plot(Y_test1, label='Target')
for i in range(len(forecasting_DL)):
  plt.plot(forecasting_DL[i], label=model_names_DL[i], linestyle='--')
plt.xlim(3850,len(forecasting_DL[i])) # 3850
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize='8')
plt.grid()
plt.show()


col_names, MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var = ['Metrics','RNN', 'GRU', 'LSTM'], ["MSE"], ["RMSE"], ["MAE"], ["R2"],['cnSMAPE'],['P_Value_PS'],['P_Value_TT'], ['P_Value_Var']

for k in range(3):
  MSE.append(round(mean_squared_error(Y_test1, forecasting_DL[k], squared=False),5))
  RMSE.append(mean_squared_error(Y_test1, forecasting_DL[k], squared=True))
  MAE.append(round(mean_absolute_error(Y_test1, forecasting_DL[k]),5))
  R2.append(round(r2_score(Y_test1, forecasting_DL[k]),5))
  mape=mean_absolute_percentage_error(Y_test1, forecasting_DL[k])
  smape = 2 * mape * 100 / (100 - mape)
  cnSMAPE.append(round(1-(smape/2),5))
  correlation, p_value = stats.pearsonr(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_PS.append(p_value)
  correlation, p_value = stats.ttest_ind(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_TT.append(p_value)
  statistic, p_value3 = bartlett(Y_test1.reshape(len(Y_test1)), forecasting_DL[k].reshape(len(Y_test1)))
  P_Value_Var.append(p_value3)

tablas = [MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var]

print(tabulate(tablas, headers=col_names, tablefmt="fancy_grid"))
# Out:
# 124/124 [==============================] - 0s 2ms/step
# 124/124 [==============================] - 0s 3ms/step
# 124/124 [==============================] - 0s 3ms/step
# ╒═════════════╤════════════╤════════════╤═════════════╕
# │ Metrics     │        RNN │        GRU │        LSTM │
# ╞═════════════╪════════════╪════════════╪═════════════╡
# │ MSE         │ 0.04395    │ 0.04482    │ 0.06878     │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ RMSE        │ 0.00193122 │ 0.00200922 │ 0.00473068  │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ MAE         │ 0.0332     │ 0.03449    │ 0.05145     │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ R2          │ 0.95208    │ 0.95015    │ 0.88262     │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ cnSMAPE     │ 0.943      │ 0.9394     │ 0.92217     │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ P_Value_PS  │ 0          │ 0          │ 0           │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ P_Value_TT  │ 0.336745   │ 0.350221   │ 9.83274e-12 │
# ├─────────────┼────────────┼────────────┼─────────────┤
# │ P_Value_Var │ 0.00356682 │ 0.0022869  │ 1.62048e-38 │
# ╘═════════════╧════════════╧════════════╧═════════════╛

# %% [markdown]
# ## TimeStep =24

# %% [markdown]
# ### Conjunto de Entrenamiento

# %%
#  Particion X,Y y Time_step/step_back/window
step_back = 1

X1, Y1 = TrainingSets(data = Ts1, dataξ = out,step_back=step_back)


#  Particion Train_Test

Part = 0.8

# Serie 1
X_test1 = X1[int(len(X1)*0.8):]
X_train1 = X1[:int(len(X1)*0.8)]
# X_test1=X_test1[:,0,:]
# X_train1=X_train1[:,0,:]

Y_test1 = Y1[int(len(Y1)*0.8):]
Y_train1 = Y1[:int(len(Y1)*0.8)]
# Y_test1=Y_test1[:,0]
# Y_train1=Y_train1[:,0]

# %% [markdown]
# ### LSTM

# %%
model_LSTM = keras.models.Sequential([
                                     keras.layers.LSTM(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.LSTM(100, return_sequences=True),
                                     keras.layers.LSTM(100, return_sequences=True),
                                     keras.layers.LSTM(1)
])
model_LSTM.summary()

# Training

model_LSTM.compile(loss="mse", optimizer="adam", metrics=['mae', 'mse'])
history = model_LSTM.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 100)            50000
#
#  lstm_5 (LSTM)               (None, 1, 100)            80400
#
#  lstm_6 (LSTM)               (None, 1, 100)            80400
#
#  lstm_7 (LSTM)               (None, 1)                 408
#
# =================================================================
# Total params: 211,208
# Trainable params: 211,208
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 16s 64ms/step - loss: 0.2776 - mae: 0.4874 - mse: 0.2776 - val_loss: 0.1490 - val_mae: 0.3523 - val_mse: 0.1490 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0407 - mae: 0.1643 - mse: 0.0407 - val_loss: 0.0232 - val_mae: 0.1349 - val_mse: 0.0232 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0200 - mae: 0.1228 - mse: 0.0200 - val_loss: 0.0199 - val_mae: 0.1186 - val_mse: 0.0199 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0132 - mae: 0.1011 - mse: 0.0132 - val_loss: 0.0132 - val_mae: 0.0964 - val_mse: 0.0132 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0087 - mae: 0.0802 - mse: 0.0087 - val_loss: 0.0094 - val_mae: 0.0799 - val_mse: 0.0094 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.
early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ANN

# %%
model_ANN = keras.models.Sequential([
                                     keras.layers.Dense(100, input_shape=(step_back,Ts1.shape[1],)),
                                     keras.layers.Dense(100),
                                     keras.layers.Dense(100),
                                     keras.layers.Dense(1)
])
model_ANN.summary()

# Training

model_ANN.compile(loss="mse", optimizer="adam", metrics=['mae', 'mse'])
history = model_ANN.fit(X_train1, Y_train1, epochs=N, batch_size=bsz,callbacks=callbacks, validation_split=0.2) #
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1, 100)            2500
#
#  dense_5 (Dense)             (None, 1, 100)            10100
#
#  dense_6 (Dense)             (None, 1, 100)            10100
#
#  dense_7 (Dense)             (None, 1, 1)              101
#
# =================================================================
# Total params: 22,801
# Trainable params: 22,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 2s 16ms/step - loss: 0.0916 - mae: 0.2428 - mse: 0.0916 - val_loss: 0.0639 - val_mae: 0.2101 - val_mse: 0.0639 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0463 - mae: 0.1849 - mse: 0.0463 - val_loss: 0.0440 - val_mae: 0.1821 - val_mse: 0.0440 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0425 - mae: 0.1798 - mse: 0.0425 - val_loss: 0.0434 - val_mae: 0.1813 - val_mse: 0.0434 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0418 - mae: 0.1791 - mse: 0.0418 - val_loss: 0.0426 - val_mae: 0.1802 - val_mse: 0.0426 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0415 - mae: 0.1788 - mse: 0.0415 - val_loss: 0.0423 - val_mae: 0.1799 - val_mse: 0.0423 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0414 - mae: 0.1785 - mse: 0.0414 - val_loss: 0.0456 - val_mae: 0.1843 - val_mse: 0.0456 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0413 - mae: 0.1784 - mse: 0.0413 - val_loss: 0.0411 - val_mae: 0.1782 - val_mse: 0.0411 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0420 - mae: 0.1795 - mse: 0.0420 - val_loss: 0.0436 - val_mae: 0.1816 - val_mse: 0.0436 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0414 - mae: 0.1784 - mse: 0.0414 - val_loss: 0.0404 - val_mae: 0.1772 - val_mse: 0.0404 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0414 - mae: 0.1787 - mse: 0.0414 - val_loss: 0.0417 - val_mae: 0.1790 - val_mse: 0.0417 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0412 - mae: 0.1785 - mse: 0.0412 - val_loss: 0.0433 - val_mae: 0.1813 - val_mse: 0.0433 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0416 - mae: 0.1787 - mse: 0.0416 - val_loss: 0.0403 - val_mae: 0.1771 - val_mse: 0.0403 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0414 - mae: 0.1787 - mse: 0.0414 - val_loss: 0.0399 - val_mae: 0.1764 - val_mse: 0.0399 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0411 - mae: 0.1780 - mse: 0.0411 - val_loss: 0.0477 - val_mae: 0.1872 - val_mse: 0.0477 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0409 - mae: 0.1780 - mse: 0.0409 - val_loss: 0.0414 - val_mae: 0.1787 - val_mse: 0.0414 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0409 - mae: 0.1781 - mse: 0.0409 - val_loss: 0.0453 - val_mae: 0.1840 - val_mse: 0.0453 - lr: 0.0010
# Epoch 17/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0410 - mae: 0.1781 - mse: 0.0410 - val_loss: 0.0430 - val_mae: 0.1809 - val_mse: 0.0430 - lr: 0.0010
# Epoch 18/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0408 - mae: 0.1779 - mse: 0.0408 - val_loss: 0.0414 - val_mae: 0.1787 - val_mse: 0.0414 - lr: 0.0010
# Epoch 19/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0407 - mae: 0.1778 - mse: 0.0407 - val_loss: 0.0434 - val_mae: 0.1814 - val_mse: 0.0434 - lr: 5.0000e-04
# Epoch 20/100
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0407 - mae: 0.1778 - mse: 0.0407 - val_loss: 0.0463 - val_mae: 0.1853 - val_mse: 0.0463 - lr: 5.0000e-04
# Epoch 20: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### GRU

# %%
model_GRU = keras.models.Sequential([
                                     keras.layers.GRU(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.GRU(100, return_sequences=True),
                                     keras.layers.GRU(100, return_sequences=True),
                                     keras.layers.GRU(1)
])
model_GRU.summary()

# Training
metrics=['mae', 'mse']

model_GRU.compile(loss="mse", optimizer="adam", metrics=metrics)
history = model_GRU.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None, 1, 100)            37800
#
#  gru_5 (GRU)                 (None, 1, 100)            60600
#
#  gru_6 (GRU)                 (None, 1, 100)            60600
#
#  gru_7 (GRU)                 (None, 1)                 309
#
# =================================================================
# Total params: 159,309
# Trainable params: 159,309
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 8s 59ms/step - loss: 0.1043 - mae: 0.2529 - mse: 0.1043 - val_loss: 0.0244 - val_mae: 0.1348 - val_mse: 0.0244 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0220 - mae: 0.1289 - mse: 0.0220 - val_loss: 0.0126 - val_mae: 0.0982 - val_mse: 0.0126 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0064 - mae: 0.0675 - mse: 0.0064 - val_loss: 0.0039 - val_mae: 0.0522 - val_mse: 0.0039 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0034 - mae: 0.0479 - mse: 0.0034 - val_loss: 0.0032 - val_mae: 0.0472 - val_mse: 0.0032 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0030 - mae: 0.0445 - mse: 0.0030 - val_loss: 0.0029 - val_mae: 0.0444 - val_mse: 0.0029 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0026 - mae: 0.0416 - mse: 0.0026 - val_loss: 0.0027 - val_mae: 0.0426 - val_mse: 0.0027 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0024 - mae: 0.0390 - mse: 0.0024 - val_loss: 0.0023 - val_mae: 0.0382 - val_mse: 0.0023 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0022 - mae: 0.0367 - mse: 0.0022 - val_loss: 0.0022 - val_mae: 0.0372 - val_mse: 0.0022 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0020 - mae: 0.0352 - mse: 0.0020 - val_loss: 0.0025 - val_mae: 0.0390 - val_mse: 0.0025 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0019 - mae: 0.0340 - mse: 0.0019 - val_loss: 0.0020 - val_mae: 0.0349 - val_mse: 0.0020 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0019 - mae: 0.0334 - mse: 0.0019 - val_loss: 0.0022 - val_mae: 0.0365 - val_mse: 0.0022 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0018 - mae: 0.0326 - mse: 0.0018 - val_loss: 0.0020 - val_mae: 0.0342 - val_mse: 0.0020 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0018 - mae: 0.0320 - mse: 0.0018 - val_loss: 0.0018 - val_mae: 0.0327 - val_mse: 0.0018 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017 - mae: 0.0315 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0339 - val_mse: 0.0020 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0017 - mae: 0.0311 - mse: 0.0017 - val_loss: 0.0018 - val_mae: 0.0329 - val_mse: 0.0018 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0310 - mse: 0.0017 - val_loss: 0.0022 - val_mae: 0.0359 - val_mse: 0.0022 - lr: 0.0010
# Epoch 17/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0017 - mae: 0.0311 - mse: 0.0017 - val_loss: 0.0017 - val_mae: 0.0321 - val_mse: 0.0017 - lr: 0.0010
# Epoch 18/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0016 - mae: 0.0304 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0320 - val_mse: 0.0017 - lr: 0.0010
# Epoch 19/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0305 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0324 - val_mse: 0.0018 - lr: 0.0010
# Epoch 20/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0016 - mae: 0.0298 - mse: 0.0016 - val_loss: 0.0018 - val_mae: 0.0321 - val_mse: 0.0018 - lr: 0.0010
# Epoch 21/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0016 - mae: 0.0302 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0320 - val_mse: 0.0017 - lr: 0.0010
# Epoch 22/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - mae: 0.0299 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0317 - val_mse: 0.0017 - lr: 0.0010
# Epoch 23/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0329 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 24/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0320 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 25/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0317 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 26/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0017 - val_mae: 0.0318 - val_mse: 0.0017 - lr: 5.0000e-04
# Epoch 27/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0016 - mae: 0.0296 - mse: 0.0016 - val_loss: 0.0019 - val_mae: 0.0330 - val_mse: 0.0019 - lr: 5.0000e-04
# Epoch 28/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0015 - mae: 0.0293 - mse: 0.0015 - val_loss: 0.0017 - val_mae: 0.0321 - val_mse: 0.0017 - lr: 2.5000e-04
# Epoch 29/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015 - mae: 0.0293 - mse: 0.0015 - val_loss: 0.0018 - val_mae: 0.0325 - val_mse: 0.0018 - lr: 2.5000e-04
# Epoch 29: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# ### RNN

# %%
model_RNN = keras.models.Sequential([
                                     keras.layers.SimpleRNN(100, return_sequences=True, input_shape=[step_back,Ts1.shape[1]]),
                                     keras.layers.SimpleRNN(100, return_sequences=True),
                                     keras.layers.SimpleRNN(100, return_sequences=True),
                                     keras.layers.SimpleRNN(1)
])
model_RNN.summary()

# Training

metrics=['mae', 'mse']
model_RNN.compile(loss="mse", optimizer="adam", metrics=metrics)
history = model_RNN.fit(X_train1, Y_train1, epochs=N, batch_size=bsz, callbacks=callbacks, validation_split=0.2)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 1, 100)            12500
#
#  simple_rnn_5 (SimpleRNN)    (None, 1, 100)            20100
#
#  simple_rnn_6 (SimpleRNN)    (None, 1, 100)            20100
#
#  simple_rnn_7 (SimpleRNN)    (None, 1)                 102
#
# =================================================================
# Total params: 52,802
# Trainable params: 52,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 5s 33ms/step - loss: 0.1300 - mae: 0.2980 - mse: 0.1300 - val_loss: 0.0417 - val_mae: 0.1899 - val_mse: 0.0417 - lr: 0.0010
# Epoch 2/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0115 - mae: 0.0859 - mse: 0.0115 - val_loss: 0.0041 - val_mae: 0.0514 - val_mse: 0.0041 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0043 - mae: 0.0523 - mse: 0.0043 - val_loss: 0.0048 - val_mae: 0.0564 - val_mse: 0.0048 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0033 - mae: 0.0459 - mse: 0.0033 - val_loss: 0.0036 - val_mae: 0.0475 - val_mse: 0.0036 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0030 - mae: 0.0433 - mse: 0.0030 - val_loss: 0.0035 - val_mae: 0.0467 - val_mse: 0.0035 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0028 - mae: 0.0420 - mse: 0.0028 - val_loss: 0.0034 - val_mae: 0.0455 - val_mse: 0.0034 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0027 - mae: 0.0410 - mse: 0.0027 - val_loss: 0.0034 - val_mae: 0.0453 - val_mse: 0.0034 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0026 - mae: 0.0403 - mse: 0.0026 - val_loss: 0.0032 - val_mae: 0.0441 - val_mse: 0.0032 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0025 - mae: 0.0397 - mse: 0.0025 - val_loss: 0.0030 - val_mae: 0.0423 - val_mse: 0.0030 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0025 - mae: 0.0392 - mse: 0.0025 - val_loss: 0.0029 - val_mae: 0.0417 - val_mse: 0.0029 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0024 - mae: 0.0386 - mse: 0.0024 - val_loss: 0.0028 - val_mae: 0.0409 - val_mse: 0.0028 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0023 - mae: 0.0381 - mse: 0.0023 - val_loss: 0.0028 - val_mae: 0.0411 - val_mse: 0.0028 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0023 - mae: 0.0376 - mse: 0.0023 - val_loss: 0.0028 - val_mae: 0.0404 - val_mse: 0.0028 - lr: 0.0010
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0023 - mae: 0.0372 - mse: 0.0023 - val_loss: 0.0025 - val_mae: 0.0386 - val_mse: 0.0025 - lr: 0.0010
# Epoch 15/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0022 - mae: 0.0368 - mse: 0.0022 - val_loss: 0.0027 - val_mae: 0.0399 - val_mse: 0.0027 - lr: 0.0010
# Epoch 16/100
# 25/25 [==============================] - 1s 25ms/step - loss: 0.
-04
# Epoch 38/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0314 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0344 - val_mse: 0.0020 - lr: 2.5000e-04
# Epoch 39/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0017 - mae: 0.0314 - mse: 0.0017 - val_loss: 0.0021 - val_mae: 0.0353 - val_mse: 0.0021 - lr: 1.2500e-04
# Epoch 40/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0017 - mae: 0.0312 - mse: 0.0017 - val_loss: 0.0021 - val_mae: 0.0349 - val_mse: 0.0021 - lr: 1.2500e-04
# Epoch 41/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0312 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0344 - val_mse: 0.0020 - lr: 1.2500e-04
# Epoch 42/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0017 - mae: 0.0312 - mse: 0.0017 - val_loss: 0.0020 - val_mae: 0.0345 - val_mse: 0.0020 - lr: 1.2500e-04
# Epoch 43/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0312 - mse: 0.0017 - val_loss: 0.0021 - val_mae: 0.0348 - val_mse: 0.0021 - lr: 1.2500e-04
# Epoch 44/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0017 - mae: 0.0311 - mse: 0.0017 - val_loss: 0.0021 - val_mae: 0.0348 - val_mse: 0.0021 - lr: 1.0000e-04
# Epoch 45/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0017 - mae: 0.0311 - mse: 0.0017 - val_loss: 0.0021 - val_mae: 0.0350 - val_mse: 0.0021 - lr: 1.0000e-04
# Epoch 45: early stopping

# %%
hpd = pd.DataFrame(history.history)
hpd.plot()
plt.title('Todas las métricas de rendmiento', c='r')
plt.grid(True)
plt.show()

# %% [markdown]
# # Rendimiento

# %%
forecasting_RNN  = model_RNN.predict(X_test1)
forecasting_GRU  = model_GRU.predict(X_test1)
forecasting_LSTM = model_LSTM.predict(X_test1)
forecasting_ANN = model_ANN.predict(X_test1)

forecasting_DL2 = [forecasting_RNN, forecasting_GRU, forecasting_LSTM,forecasting_ANN.reshape(forecasting_ANN.shape[0],1)]
model_names_DL = ['RNN', 'GRU', 'LSTM','ANN']

plt.figure(figsize=(7.5,5))
plt.plot(Y_test1, label='Target')
for i in range(len(forecasting_DL2)):
  plt.plot(forecasting_DL2[i], label=model_names_DL[i], linestyle='--')
plt.xlim(3850,len(forecasting_DL2[i])) # 3850
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize='8')
plt.grid()
plt.show()

col_names, MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var = ['Metrics','RNN', 'GRU', 'LSTM','ANN'], ["MSE"], ["RMSE"], ["MAE"], ["R2"],['cnSMAPE'],['P_Value_PS'],['P_Value_TT'], ['P_Value_Var']
for k in range(4):
  MSE.append(round(mean_squared_error(Y_test1, forecasting_DL2[k], squared=False),5))
  RMSE.append(mean_squared_error(Y_test1, forecasting_DL2[k], squared=True))
  MAE.append(round(mean_absolute_error(Y_test1, forecasting_DL2[k]),5))
  R2.append(round(r2_score(Y_test1, forecasting_DL2[k]),5))
  mape=mean_absolute_percentage_error(Y_test1, forecasting_DL2[k])
  smape = 2 * mape * 100 / (100 - mape)
  cnSMAPE.append(round(1-(smape/2),5))
  correlation, p_value = stats.pearsonr(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_PS.append(p_value)
  correlation, p_value = stats.ttest_ind(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_TT.append(p_value)
  statistic, p_value3 = bartlett(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_Var.append(p_value3)

tablas = [MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var]

print(tabulate(tablas, headers=col_names, tablefmt="fancy_grid"))
# Out:
# 124/124 [==============================] - 1s 2ms/step
# 124/124 [==============================] - 1s 3ms/step
# 124/124 [==============================] - 2s 3ms/step
# 124/124 [==============================] - 0s 2ms/step
# ╒═════════════╤═════════════╤════════════╤═════════════╤═══════════════╕
# │ Metrics     │         RNN │        GRU │        LSTM │           ANN │
# ╞═════════════╪═════════════╪════════════╪═════════════╪═══════════════╡
# │ MSE         │ 0.04751     │ 0.04379    │ 0.0686      │  0.23368      │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ RMSE        │ 0.00225749  │ 0.00191796 │ 0.00470606  │  0.0546064    │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ MAE         │ 0.0365      │ 0.03344    │ 0.05158     │  0.20121      │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ R2          │ 0.94398     │ 0.95241    │ 0.88323     │ -0.35495      │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ cnSMAPE     │ 0.93782     │ 0.94155    │ 0.92151     │  0.66277      │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_PS  │ 0           │ 0          │ 0           │  0            │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_TT  │ 0.0756468   │ 0.763994   │ 2.09568e-10 │  1.45154e-206 │
# ├─────────────┼─────────────┼────────────┼─────────────┼───────────────┤
# │ P_Value_Var │ 5.19871e-10 │ 0.00538156 │ 2.06293e-38 │  0            │
# ╘═════════════╧═════════════╧════════════╧═════════════╧═══════════════╛

# %%
forecasting_RNN  = model_RNN.predict(X_test1)
forecasting_GRU  = model_GRU.predict(X_test1)
forecasting_LSTM = model_LSTM.predict(X_test1)

forecasting_DL2 = [forecasting_RNN, forecasting_GRU, forecasting_LSTM]
model_names_DL = ['RNN', 'GRU', 'LSTM']

plt.figure(figsize=(7.5,5))
plt.plot(Y_test1, label='Target')
for i in range(len(forecasting_DL2)):
  plt.plot(forecasting_DL2[i], label=model_names_DL[i], linestyle='--')
plt.xlim(3850,len(forecasting_DL2[i])) # 3850
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize='8')
plt.grid()
plt.show()

col_names, MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var = ['Metrics','RNN', 'GRU', 'LSTM'], ["MSE"], ["RMSE"], ["MAE"], ["R2"],['cnSMAPE'],['P_Value_PS'],['P_Value_TT'], ['P_Value_Var']
for k in range(3):
  MSE.append(round(mean_squared_error(Y_test1, forecasting_DL2[k], squared=False),5))
  RMSE.append(mean_squared_error(Y_test1, forecasting_DL2[k], squared=True))
  MAE.append(round(mean_absolute_error(Y_test1, forecasting_DL2[k]),5))
  R2.append(round(r2_score(Y_test1, forecasting_DL2[k]),5))
  mape=mean_absolute_percentage_error(Y_test1, forecasting_DL2[k])
  smape = 2 * mape * 100 / (100 - mape)
  cnSMAPE.append(round(1-(smape/2),5))
  correlation, p_value = stats.pearsonr(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_PS.append(p_value)
  correlation, p_value = stats.ttest_ind(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_TT.append(p_value)
  statistic, p_value3 = bartlett(Y_test1.reshape(len(Y_test1)), forecasting_DL2[k].reshape(len(Y_test1)))
  P_Value_Var.append(p_value3)

tablas = [MSE, RMSE, MAE, R2, cnSMAPE, P_Value_PS, P_Value_TT, P_Value_Var]

print(tabulate(tablas, headers=col_names, tablefmt="fancy_grid"))
# Out:
# 124/124 [==============================] - 0s 2ms/step
# 124/124 [==============================] - 0s 3ms/step
# 124/124 [==============================] - 0s 3ms/step
# ╒═════════════╤═════════════╤════════════╤═════════════╕
# │ Metrics     │         RNN │        GRU │        LSTM │
# ╞═════════════╪═════════════╪════════════╪═════════════╡
# │ MSE         │ 0.04751     │ 0.04379    │ 0.0686      │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ RMSE        │ 0.00225749  │ 0.00191796 │ 0.00470606  │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ MAE         │ 0.0365      │ 0.03344    │ 0.05158     │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ R2          │ 0.94398     │ 0.95241    │ 0.88323     │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ cnSMAPE     │ 0.93782     │ 0.94155    │ 0.92151     │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ P_Value_PS  │ 0           │ 0          │ 0           │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ P_Value_TT  │ 0.0756468   │ 0.763994   │ 2.09568e-10 │
# ├─────────────┼─────────────┼────────────┼─────────────┤
# │ P_Value_Var │ 5.19871e-10 │ 0.00538156 │ 2.06293e-38 │
# ╘═════════════╧═════════════╧════════════╧═════════════╛
